# %% [markdown]
# #### Import Dependencies

# %%
from langsmith import Client

# %% [markdown]
# #### Attach Feedback to a specific trace in Langsmith

# %%
client = Client()

# %%
RUN_ID = "019c9153-432b-7250-a5a6-989676eecc6c"

# %%
client.create_feedback(
    run_id=RUN_ID,
    key="feedback",
    score=0,
    feedback_source_type='api'
)
# Out:
# Feedback(id=UUID('019c918f-54bc-7253-9aa2-3dd1a9615f50'), created_at=datetime.datetime(2026, 2, 24, 21, 30, 15, 612156, tzinfo=datetime.timezone.utc), modified_at=datetime.datetime(2026, 2, 24, 21, 30, 15, 612157, tzinfo=datetime.timezone.utc), run_id=UUID('019c9153-432b-7250-a5a6-989676eecc6c'), trace_id=None, key='feedback', score=0, value=None, comment=None, correction=None, feedback_source=FeedbackSourceBase(type='api', metadata={}, user_id=None, user_name=None), session_id=None, comparative_experiment_id=None, feedback_group_id=None, extra=None)
